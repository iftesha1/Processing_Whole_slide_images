# %% [markdown]
# ## Converting the  WSI of Reactive lymph node to tiles

# %%
import openslide
from openslide import open_slide
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
slide = open_slide("whole_slide_images/Reactive hyperplasia.svs")

# %%
slide_props = slide.properties
print(slide_props)
# Out:
# <_PropertyMap {'aperio.AppMag': '40', 'aperio.MPP': '0.241158', 'openslide.comment': 'Aperio Image Library v10.2.24\r\r\n26187x27552 [0,0 26187x27552] [256x256] JPEG/YCbCr Q = 75|AppMag = 40|MPP = 0.241158', 'openslide.level-count': '3', 'openslide.level[0].downsample': '1', 'openslide.level[0].height': '27552', 'openslide.level[0].tile-height': '256', 'openslide.level[0].tile-width': '256', 'openslide.level[0].width': '26187', 'openslide.level[1].downsample': '4.0002291475710354', 'openslide.level[1].height': '6888', 'openslide.level[1].tile-height': '256', 'openslide.level[1].tile-width': '256', 'openslide.level[1].width': '6546', 'openslide.level[2].downsample': '16.003361858190708', 'openslide.level[2].height': '1722', 'openslide.level[2].tile-height': '256', 'openslide.level[2].tile-width': '256', 'openslide.level[2].width': '1636', 'openslide.mpp-x': '0.24115800000000001', 'openslide.mpp-y': '0.24115800000000001', 'openslide.objective-power': '40', 'openslide.quickhash-1': '0476f5a54c813d3a24ba666409266d6f31a29accadcd4f3b75a49e20583cd5f1', 'openslide.vendor': 'aperio', 'tiff.ImageDescription': 'Aperio Image Library v10.2.24\r\r\n26187x27552 [0,0 26187x27552] [256x256] JPEG/YCbCr Q = 75|AppMag = 40|MPP = 0.241158', 'tiff.ResolutionUnit': 'inch'}>

# %%
print("Vendor is:", slide_props['openslide.vendor'])
# Out:
# Vendor is: aperio

# %% [markdown]
# as it is a svs file so we get the vendor as aperio

# %%
print("Pixel size of X in micron is:", slide_props['openslide.mpp-x'])
print("Pixel size of Y in micron is:", slide_props['openslide.mpp-y'])
# Out:
# Pixel size of X in micron is: 0.24115800000000001
# Pixel size of Y in micron is: 0.24115800000000001

# %% [markdown]
# As it is from optical microscope so it is an isometric pixel(i.e. the x-pixel and y-pixel are of same size)

# %%
#Objective used to capture the image

objective = float(slide.properties[openslide.PROPERTY_NAME_OBJECTIVE_POWER])
print("The objective power is: ", objective)
# Out:
# The objective power is:  40.0

# %% [markdown]
# This indicated that the slide has been collected at 40X

# %%
# get slide dimensions for the level 0 - max resolution level
slide_dims = slide.dimensions
print(slide_dims)
# Out:
# (26187, 27552)

# %%
#Get a thumbnail of the image and visualize
slide_thumb_600 = slide.get_thumbnail(size=(600, 600))
slide_thumb_600.show()

# %%
#Convert thumbnail to numpy array
slide_thumb_600_np = np.array(slide_thumb_600)
plt.figure(figsize=(8,8))
plt.imshow(slide_thumb_600_np)

# %%
#Get slide dims at each level. Remember that whole slide images store information
#as pyramid at various levels
dims = slide.level_dimensions

# %%
num_levels = len(dims)
print("Number of levels in this image are:", num_levels)
# Out:
# Number of levels in this image are: 3

# %%
print("Dimensions of various levels in this image are:", dims)
# Out:
# Dimensions of various levels in this image are: ((26187, 27552), (6546, 6888), (1636, 1722))

# %%
#By how much are levels downsampled from the original image?
factors = slide.level_downsamples
print("Each level is downsampled by an amount of: ", factors)
# Out:
# Each level is downsampled by an amount of:  (1.0, 4.000229147571035, 16.003361858190708)

# %%
#Copy an image from a level
level3_dim = dims[2]
#Give pixel coordinates (top left pixel in the original large image)
#Also give the level number (for level 3 we are providing a valueof 2)
#Size of your output image
#Remember that the output would be a RGBA image (Not, RGB)
level3_img = slide.read_region((0,0), 2, level3_dim) #Pillow object, mode=RGBA

# %%
#Convert the image to RGB
level3_img_RGB = level3_img.convert('RGB')
level3_img_RGB.show()

# %%
#Convert the image into numpy array for processing
level3_img_np = np.array(level3_img_RGB)
plt.imshow(level3_img_np)

# %%
#Return the best level for displaying the given downsample.
SCALE_FACTOR = 32
best_level = slide.get_best_level_for_downsample(SCALE_FACTOR)
#Here it returns the best level to be 2 (third level)
#If you change the scale factor to 2, it will suggest the best level to be 0 (our 1st level)

# %%
from openslide.deepzoom import DeepZoomGenerator

# %%
#Generate object for tiles using the DeepZoomGenerator
tiles = DeepZoomGenerator(slide, tile_size=256, overlap=0, limit_bounds=False)
#Here, we have divided our svs into tiles of size 256 with no overlap.

# %%
#The tiles object also contains data at many levels. 
#To check the number of levels
print("The number of levels in the tiles object are: ", tiles.level_count)
# Out:
# The number of levels in the tiles object are:  16

# %%
print("The dimensions of data in each level are: ", tiles.level_dimensions)
# Out:
# The dimensions of data in each level are:  ((1, 1), (2, 2), (4, 4), (7, 7), (13, 14), (26, 27), (52, 54), (103, 108), (205, 216), (410, 431), (819, 861), (1637, 1722), (3274, 3444), (6547, 6888), (13094, 13776), (26187, 27552))

# %%
#Total number of tiles in the tiles object
print("Total number of tiles = : ", tiles.tile_count)
# Out:
# Total number of tiles = :  14894

# %%
#How many tiles at a specific level?
level_num = 11
print("Tiles shape at level ", level_num, " is: ", tiles.level_tiles[level_num])
print("This means there are ", tiles.level_tiles[level_num][0]*tiles.level_tiles[level_num][1], " total tiles in this level")
# Out:
# Tiles shape at level  15  is:  (103, 108)
# This means there are  11124  total tiles in this level

# %%
#Dimensions of the tile (tile size) for a specific tile from a specific layer
tile_dims = tiles.get_tile_dimensions(11, (3,4)) #Provide deep zoom level and address (column, row)
tile_dims
# Out:
# (256, 256)

# %%
#Tile count at the highest resolution level (level 16 in our tiles)
tile_count_in_large_image = tiles.level_tiles[15] #126 x 151 (32001/256 = 126 with no overlap pixels)
#Check tile size for some random tile
tile_dims = tiles.get_tile_dimensions(15, (100,102))
#Last tiles may not have full 256x256 dimensions as our large image is not exactly divisible by 256
tile_dims = tiles.get_tile_dimensions(15, (102,107))

# %%
single_tile = tiles.get_tile(15, (50, 50)) #Provide deep zoom level and address (column, row)
single_tile_RGB = single_tile.convert('RGB')
single_tile_RGB.show()

# %%
###### Saving each tile to local directory
cols, rows = tiles.level_tiles[11]

# %%
import os
tile_dir = "whole_slide_images/Reactive hyperplasia tiles/"
for row in range(rows):
    for col in range(cols):
        tile_name = os.path.join(tile_dir, '%d_%d' % (col, row))
        print("Now saving tile with title: ", tile_name)
        temp_tile = tiles.get_tile(11, (col, row))
        temp_tile_RGB = temp_tile.convert('RGB')
        temp_tile_np = np.array(temp_tile_RGB)
        plt.imsave(tile_name + ".png", temp_tile_np)
# Out:
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_0
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_1
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_2
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_3
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_4
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_5
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/0_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/1_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/2_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/3_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/4_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/5_6
# Now saving tile with title:  whole_slide_images/Reactive hyperplasia tiles/6_6
